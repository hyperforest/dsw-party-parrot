# %% [markdown]
# # Notebook for DSW Telkomsel 2023 - Party Parrot

# %%
import os
import re
import duckdb
import numpy as np
import pandas as pd

from fuzzywuzzy import fuzz
from tqdm import tqdm

# %load_ext autoreload
# %autoreload 2
# Out:
# c:\Users\FLP-13-Rimba\miniconda3\envs\dsw-telkomsel-2023\lib\site-packages\fuzzywuzzy\fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# # Read Data

# %%
df_name = pd.read_excel('datasets/raw/product_name.xlsx')
catalog = pd.read_excel('datasets/raw/product_catalog.xlsx')

df_name.rename(columns={'Product Name': 'product_name'}, inplace=True)
catalog.rename(columns={
    'Product SKU': 'product_sku',
    'Brand': 'brand',
    'Type': 'type',
    'Formula': 'formula'
}, inplace=True)

df_name = df_name.dropna()
df_name
# Out:
#                         product_name
# 0                   Pupuk Urea N 46%
# 1            Pupuk Amonium Sulfat ZA
# 2           Pupuk Super Fosfat SP-36
# 3                  Pupuk NPK Phonska
# 4           Pupuk NPK Formula Khusus
# ...                              ...
# 43997      Extra one 680 EC @ 250 ml
# 43998      Extra One 680 SC @ 500 ml
# 43999      JARING ARWANA @ 100 METER
# 44000        Terong Puma F1 @ 5 gram
# 44001  Terong Liberto Hijau @ 5 gram
#
# [44001 rows x 1 columns]

# %%
catalog
# Out:
#         product_sku    brand      type formula
# 0        Urea Petro     PIHC      Urea     NaN
# 1          Urea PIM     PIHC      Urea     NaN
# 2       Urea Nitrea     PIHC      Urea     NaN
# 3    Urea Daun Buah     PIHC      Urea     NaN
# 4        Urea Pusri     PIHC      Urea     NaN
# ..              ...      ...       ...     ...
# 182        Mestical  LaoYing  Nitrogen     NaN
# 183       Mesti-GAS  LaoYing        ZA     NaN
# 184          Mestac  LaoYing  Nitrogen     NaN
# 185     MestiKisrit  LaoYing        Mg     NaN
# 186  Borate Evermax  LaoYing     Mikro     NaN
#
# [187 rows x 4 columns]

# %% [markdown]
# # Preprocessing

# %%
def is_containing_non_alphanumeric(string):
    return not bool(re.search(r'[^a-zA-Z0-9 ]', string))

df_name['is_only_alphanum'] = df_name['product_name'].apply(is_containing_non_alphanumeric)
catalog['is_only_alphanum'] = catalog['product_sku'].apply(is_containing_non_alphanumeric)

# %%
def clean(s):
    s = s.lower()

    # give spaces before and after the special characters, that are not number or decimal number
    # e.g. 'abc+c' to 'abc + c', but '12.9' not to '12 . 9'
    s = re.sub(r'([^\d\.,-]+)', r' \1 ', s)

    # separate value and units like "100ml" to "100 ml" or "50g" to "50 g"
    # that are not wrapped in <...> bracket
    s = re.sub(r'(\d+)([a-zA-Z]+)', r'\1 \2', s)

    # make chemical formula separator uniform to 'x', i.e. '4.5 - 3.6 - 2.1' to '4.5x3.6x2.1'
    s = re.sub(r'(\d+\.?,?\d*)[×x\+,\. |-]+(\d+\.?,?\d*)[×x\+,\. |-]+(\d+\.?,?\d*)', r'\1x\2x\3', s)

    # remove extra spaces
    s = re.sub(r'\s+', ' ', s)
    
    return s

catalog['clean_sku'] = catalog.product_sku.apply(clean)
df_name['clean_name'] = df_name.product_name.apply(clean)

# %%
df_name[df_name.is_only_alphanum == False].loc[5200:5400]
# Out:
#                      product_name  is_only_alphanum  \
# 5203       npk kujang 30.6.8 25kg             False
# 5211      Pakan Ayam  311/511/512             False
# 5213              Super-K 500 grm             False
# 5218          Lanet 25 wp. 15 grm             False
# 5220       Lannete 40 SP. 100 grm             False
# 5225                X-TRAIL 100ml             False
# 5243  selang putih 0.20 x 15 x 20             False
# 5244      selang putih 0.20x20x50             False
# 5245             0,20×15×50 putih             False
# 5249                   sp26 -25kg             False
# 5294          NPK Nitrat 16-16-16             False
# 5307                        PAKU.             False
# 5310             PAKU OSOK KAYU.B             False
# 5311            PAKU OSOK KAYU .K             False
# 5314             PAKU RENG BAMBU.             False
# 5327               Bio KCL++ 1ltr             False
# 5328             Bio KCL ++ 500ml             False
# 5329                   NPK++ 1ltr             False
# 5330                  NPK++ 500ml             False
# 5333       Phonska Plus/ZK 2,5 Kg             False
# 5337         KCC_padi&jagung 1ltr             False
# 5338           KCC kedelai&kacang             False
#
#                        clean_name
# 5203     npk kujang 30.6x8x25 kg
# 5211   pakan ayam 311 / 511 / 512
# 5213           super - k 500 grm
# 5218        lanet 25 wp . 15 grm
# 5220     lannete 40 sp . 100 grm
# 5225            x - trail 100 ml
# 5243      selang putih 0.20x15x20
# 5244      selang putih 0.20x20x50
# 5245            0,20x15x50 putih
# 5249                sp 26 -25 kg
# 5294          npk nitrat 16x16x16
# 5307                       paku .
# 5310          paku osok kayu . b
# 5311          paku osok kayu . k
# 5314            paku reng bambu .
# 5327             bio kcl++ 1 ltr
# 5328           bio kcl ++ 500 ml
# 5329                 npk++ 1 ltr
# 5330                npk++ 500 ml
# 5333      phonska plus/zk 2,5 kg
# 5337       kcc_padi&jagung 1 ltr
# 5338          kcc kedelai&kacang

# %%
catalog[catalog.is_only_alphanum == False].head(20)
# Out:
#                                    product_sku brand     type    formula  \
# 9                                    Petro-CAS  PIHC    Mikro        NaN
# 10                                 SP-36 Petro  PIHC   Fosfat        NaN
# 13                                 SP-26 Petro  PIHC   Fosfat        NaN
# 15              Phonska Plus 15-15-15+9S+0.2Zn  PIHC  Majemuk   15-15-15
# 16  NPK Kebomas 12-12-17+2MgO+0.1Zn+0.2B+0.2Fe  PIHC  Majemuk   12-12-17
# 17                     NPK Kebomas 12-6-22+3Mg  PIHC  Majemuk    12-6-22
# 18                        NPK Kebomas 15-15-15  PIHC  Majemuk   15-15-15
# 19                      PETROFERT  16-16-8+13S  PIHC  Majemuk    16-16-8
# 20                      Petro Niphos 20-20+13S  PIHC  Majemuk    20-20-0
# 21                       FERTIGRES  16-20+13S   PIHC  Majemuk    16-20-0
# 22                            NPK PIM 15-15-15  PIHC  Majemuk   15-15-15
# 23                            Nitroku 16-16-16  PIHC  Majemuk   16-16-16
# 24                NITROSKA  15-9-20+1.5MgO+3S   PIHC  Majemuk    15-9-20
# 25                        NPK Kujang 15-15-15   PIHC  Majemuk   15-15-15
# 26                           NPK Kujang 30-6-8  PIHC  Majemuk     30-6-8
# 27                 Polivit-PIM 0-0-12+48S+9MgO  PIHC   Kalium        NaN
# 28                    Solution N 28-10-10 + TE  PIHC  Majemuk   28-10-10
# 29                       Pelangi Agro 20-10-10  PIHC  Majemuk   20-10-10
# 30        Pelangi Jos 16-16-16 Coating Mikroba  PIHC  Majemuk   16-16-16
# 31                            Pelangi 16-16-16  PIHC  Majemuk   16-16-16
#
#     is_only_alphanum                                          clean_sku
# 9              False                                       petro - cas
# 10             False                                      sp -36 petro
# 13             False                                      sp -26 petro
# 15             False               phonska plus 15x15x15 + 9 s+ 0.2 zn
# 16             False   npk kebomas 12x12x17 + 2 mgo+ 0.1 zn+ 0.2 b+ ...
# 17             False                        npk kebomas 12x6x22 + 3 mg
# 18             False                               npk kebomas 15x15x15
# 19             False                          petrofert 16x16x8 + 13 s
# 20             False                           petro niphos 20x20x13 s
# 21             False                              fertigres 16x20x13 s
# 22             False                                   npk pim 15x15x15
# 23             False                                   nitroku 16x16x16
# 24             False                   nitroska 15x9x20 + 1.5 mgo+ 3 s
# 25             False                               npk kujang 15x15x15
# 26             False                                  npk kujang 30x6x8
# 27             False                polivit - pim 0x0x12 + 48 s+ 9 mgo
# 28             False                          solution n 28x10x10 + te
# 29             False                              pelangi agro 20x10x10
# 30             False              pelangi jos 16x16x16 coating mikroba
# 31             False                                   pelangi 16x16x16

# %%
df_name.to_csv('datasets/processed/product_name.tsv', sep='\t', index=False)
catalog.to_csv('datasets/processed/product_catalog.tsv', sep='\t', index=False)

# %% [markdown]
# # Levenshtein Search

# %%
joined = duckdb.query(
    '''
    WITH joined AS (
        SELECT
            dn.clean_name,
            c.product_sku,
            c.clean_sku
        FROM
            df_name AS dn
        CROSS JOIN
            catalog AS c
    )

    SELECT
        clean_name,
        product_sku,
        clean_sku,
        levenshtein(clean_name, clean_sku) AS lev_distance
    FROM joined
    '''
).to_df()

joined
# Out:
#                               clean_name     product_sku         clean_sku  \
# 0                     pupuk urea n 46 %       Urea Petro       urea petro
# 1               pupuk amonium sulfat za       Urea Petro       urea petro
# 2              pupuk super fosfat sp -36      Urea Petro       urea petro
# 3                     pupuk npk phonska       Urea Petro       urea petro
# 4              pupuk npk formula khusus       Urea Petro       urea petro
# ...                                  ...             ...               ...
# 8228182       extra one 680 ec @ 250 ml   Borate Evermax   borate evermax
# 8228183       extra one 680 sc @ 500 ml   Borate Evermax   borate evermax
# 8228184       jaring arwana @ 100 meter   Borate Evermax   borate evermax
# 8228185        terong puma f 1 @ 5 gram   Borate Evermax   borate evermax
# 8228186   terong liberto hijau @ 5 gram   Borate Evermax   borate evermax
#
#          lev_distance
# 0                  12
# 1                  19
# 2                  19
# 3                  13
# 4                  20
# ...               ...
# 8228182            20
# 8228183            21
# 8228184            21
# 8228185            20
# 8228186            24
#
# [8228187 rows x 4 columns]

# %%
result_lev = duckdb.query(
    """
    SELECT
        *
    FROM
        joined
    WHERE
        lev_distance < 2
    QUALIFY
        ROW_NUMBER() OVER (PARTITION BY clean_name ORDER BY lev_distance, clean_sku) = 1
    """
).to_df()

result_lev
# Out:
#              clean_name       product_sku          clean_sku  lev_distance
# 0              zapetro           ZA Petro          za petro              1
# 1            ferriphos          Fertiphos         fertiphos              1
# 2     mutiara 116x16x16  Mutiara 16-16-16   mutiara 16x16x16             1
# 3            z k petro           ZK Petro          zk petro              1
# 4          sp 26 petro        SP-26 Petro      sp -26 petro              1
# ..                  ...               ...                ...           ...
# 123        urea nitrea        Urea Nitrea       urea nitrea              0
# 124           urea pin           Urea PIM          urea pim              1
# 125           urea pim           Urea PIM          urea pim              0
# 126           zk petro           ZK Petro          zk petro              0
# 127          pertiphos          Fertiphos         fertiphos              1
#
# [128 rows x 4 columns]

# %%
final_res = df_name.copy()

final_res = duckdb.query(
    '''
    SELECT
        f.product_name,
        r.product_sku,
        r.clean_name,
        r.clean_sku,
        f.is_only_alphanum AS is_name_only_alphanum,
        r.lev_distance,
    FROM
        final_res AS f
    LEFT JOIN
        result_lev AS r
    ON
        f.clean_name = r.clean_name
    '''
).to_df()

final_res.iloc[-20:]
# Out:
#                      product_name                 product_sku  \
# 43981  Mutiara Grower 15-09-20+TE  Mutiara GROWER 15-09-20+TE
# 43982      YARAMILA UNIK 16.16.16      YaraMila UNIK 16-16-16
# 43983            Pelangi 16-16-16            Pelangi 16-16-16
# 43984                         lsp                         KSP
# 43985           mutiara 16 .16.16            Mutiara 16-16-16
# 43986       Nitrophonska 15-15-15        NITROPHOSKA 15-15-15
# 43987            NPK pim 15 15 15            NPK PIM 15-15-15
# 43988                       verea                        Vrea
# 43989                        Bsp                          KSP
# 43990                    fetiphos                   Fertiphos
# 43991  Mutiara Grower 18-09-20+TE  Mutiara GROWER 15-09-20+TE
# 43992            Mutiara 16,16,16            Mutiara 16-16-16
# 43993                   Phorgreen                   Phosgreen
# 43994        nitrophoska 15 15 15        NITROPHOSKA 15-15-15
# 43995            NPK PIM 15-15-15            NPK PIM 15-15-15
# 43996        NPK KEBOMAS 15 15 15        NPK Kebomas 15-15-15
# 43997                   MerokeMKP                   MerokeMOP
# 43998            Petro Bio Fertil             Petro BioFertil
# 43999                SP-26 Petro                  SP-26 Petro
# 44000         Nitroposka 15-15-15        NITROPHOSKA 15-15-15
#
#                           clean_name                      clean_sku  \
# 43981   mutiara grower 15x09x20 +te    mutiara grower 15x09x20 +te
# 43982         yaramila unik 16x16x16         yaramila unik 16x16x16
# 43983               pelangi 16x16x16               pelangi 16x16x16
# 43984                           lsp                            ksp
# 43985               mutiara 16x16x16               mutiara 16x16x16
# 43986          nitrophonska 15x15x15           nitrophoska 15x15x15
# 43987               npk pim 15x15x15               npk pim 15x15x15
# 43988                         verea                           vrea
# 43989                           bsp                            ksp
# 43990                      fetiphos                      fertiphos
# 43991   mutiara grower 18x09x20 +te    mutiara grower 15x09x20 +te
# 43992               mutiara 16x16x16               mutiara 16x16x16
# 43993                     phorgreen                      phosgreen
# 43994           nitrophoska 15x15x15           nitrophoska 15x15x15
# 43995               npk pim 15x15x15               npk pim 15x15x15
# 43996           npk kebomas 15x15x15           npk kebomas 15x15x15
# 43997                     merokemkp                      merokemop
# 43998              petro bio fertil                petro biofertil
# 43999                  sp -26 petro                   sp -26 petro
# 44000            nitroposka 15x15x15           nitrophoska 15x15x15
#
#        is_name_only_alphanum  lev_distance
# 43981                  False           0.0
# 43982                  False           0.0
# 43983                  False           0.0
# 43984                   True           1.0
# 43985                  False           0.0
# 43986                  False           1.0
# 43987                   True           0.0
# 43988                   True           1.0
# 43989                   True           1.0
# 43990                   True           1.0
# 43991                  False           1.0
# 43992                  False           0.0
# 43993                   True           1.0
# 43994                   True           0.0
# 43995                  False           0.0
# 43996                   True           0.0
# 43997                   True           1.0
# 43998                   True           1.0
# 43999                  False           0.0
# 44000                  False           1.0

# %%
final_res.to_csv('datasets/processed/final_result.tsv', sep='\t', index=False)
final_res
# Out:
#                    product_name           product_sku             clean_name  \
# 0              Pupuk Urea N 46%                  None                   None
# 1       Pupuk Amonium Sulfat ZA                  None                   None
# 2      Pupuk Super Fosfat SP-36                  None                   None
# 3             Pupuk NPK Phonska                  None                   None
# 4      Pupuk NPK Formula Khusus                  None                   None
# ...                         ...                   ...                    ...
# 43996      NPK KEBOMAS 15 15 15  NPK Kebomas 15-15-15   npk kebomas 15x15x15
# 43997                 MerokeMKP             MerokeMOP             merokemkp
# 43998          Petro Bio Fertil       Petro BioFertil      petro bio fertil
# 43999              SP-26 Petro            SP-26 Petro          sp -26 petro
# 44000       Nitroposka 15-15-15  NITROPHOSKA 15-15-15    nitroposka 15x15x15
#
#                    clean_sku  is_name_only_alphanum  lev_distance
# 0                       None                  False           NaN
# 1                       None                   True           NaN
# 2                       None                  False           NaN
# 3                       None                   True           NaN
# 4                       None                   True           NaN
# ...                      ...                    ...           ...
# 43996   npk kebomas 15x15x15                   True           0.0
# 43997             merokemop                    True           1.0
# 43998       petro biofertil                    True           1.0
# 43999          sp -26 petro                   False           0.0
# 44000   nitrophoska 15x15x15                  False           1.0
#
# [44001 rows x 6 columns]

# %% [markdown]
# # Fuzzy Search

# %%
def compute_fuzz(product_name: str, product_sku: str) -> float:
    return fuzz.ratio(product_name, product_sku)

# duckdb.create_function('compute_fuzz', compute_fuzz)

# %%
prod_name = df_name[df_name.is_only_alphanum == False].iloc[:1000]

cross_joined = pd.merge(prod_name, catalog[['product_sku', 'clean_sku']], how='cross')
cross_joined
# Out:
#              product_name  is_only_alphanum             clean_name  \
# 0        Pupuk Urea N 46%             False     pupuk urea n 46 %
# 1        Pupuk Urea N 46%             False     pupuk urea n 46 %
# 2        Pupuk Urea N 46%             False     pupuk urea n 46 %
# 3        Pupuk Urea N 46%             False     pupuk urea n 46 %
# 4        Pupuk Urea N 46%             False     pupuk urea n 46 %
# ...                   ...               ...                    ...
# 186995  Rot-up obat steek             False   rot - up obat steek
# 186996  Rot-up obat steek             False   rot - up obat steek
# 186997  Rot-up obat steek             False   rot - up obat steek
# 186998  Rot-up obat steek             False   rot - up obat steek
# 186999  Rot-up obat steek             False   rot - up obat steek
#
#            product_sku         clean_sku
# 0           Urea Petro       urea petro
# 1             Urea PIM         urea pim
# 2          Urea Nitrea      urea nitrea
# 3       Urea Daun Buah   urea daun buah
# 4           Urea Pusri       urea pusri
# ...                ...               ...
# 186995        Mestical         mestical
# 186996       Mesti-GAS      mesti - gas
# 186997          Mestac           mestac
# 186998     MestiKisrit      mestikisrit
# 186999  Borate Evermax   borate evermax
#
# [187000 rows x 5 columns]

# %%
for i in tqdm(range(len(cross_joined))):
    cross_joined.loc[i, 'fuzzy_score'] = compute_fuzz(cross_joined.loc[i, 'clean_name'], cross_joined.loc[i, 'clean_sku'])
# Out:
# 100%|██████████| 187000/187000 [00:36<00:00, 5064.02it/s]

# %%
# do cross join and compute fuzzy ratio for each pair
# by using the function `compute_fuzzy` we defined earlier,
# and infuse it with duckdb

result_fuzzy = duckdb.query(
    '''
    WITH joined AS (
        SELECT
            dn.product_name,
            c.product_sku,
            dn.clean_name,
            c.clean_sku
        FROM
            prod_name AS dn
        CROSS JOIN
            catalog AS c
    )

    SELECT
        product_name,
        product_sku,
        clean_name,
        clean_sku,
        compute_fuzz(clean_name, clean_sku) AS fuzzy_ratio
    FROM joined
    '''
).to_df()

# %%
result_fuzzy_unique = duckdb.query(
    '''
    SELECT
        *
    FROM
        result_fuzzy
    QUALIFY
        ROW_NUMBER() OVER (PARTITION BY clean_name ORDER BY fuzzy_ratio DESC, clean_sku) = 1
    '''
).to_df()

result_fuzzy_unique[result_fuzzy_unique.fuzzy_ratio > 90].shape
# Out:
# (54, 5)

# %% [markdown]
# # Post-analysis

# %%
final_res = pd.read_csv('datasets/processed/final_result_2.tsv', sep='\t')
final_res
# Out:
#                    product_name                   product_sku  \
# 0              Pupuk Urea N 46%                Urea Daun Buah
# 1       Pupuk Amonium Sulfat ZA              Ammonium Sulfate
# 2      Pupuk Super Fosfat SP-36   Triple Super Phospate (TSP)
# 3      Pupuk NPK Formula Khusus  Pak Tani Fertila  18-6-14+5S
# 4          Pupuk Organik Granul                   Urea Nitrea
# ...                         ...                           ...
# 43996        Maxxfosate Neo 1lt          Mahkota NP 16-20-12S
# 43997                    posgro                       Phosgro
# 43998                 ZA Pertro                      ZA Petro
# 43999                  nitralit                     Nitralite
# 44000       Urea Pril 50Kg PKT                     Urea Pusri
#
#                        clean_name                         clean_sku  \
# 0              pupuk urea n 46 %                    urea daun buah
# 1        pupuk amonium sulfat za                  ammonium sulfate
# 2       pupuk super fosfat sp -36      triple super phospate (tsp)
# 3       pupuk npk formula khusus    pak tani fertila 18x6x14 + 5 s
# 4           pupuk organik granul                       urea nitrea
# ...                           ...                               ...
# 43996        maxxfosate neo 1 lt             mahkota np 16x20x12 s
# 43997                     posgro                           phosgro
# 43998                  za pertro                          za petro
# 43999                   nitralit                         nitralite
# 44000        urea pril 50 kg pkt                        urea pusri
#
#        is_name_only_alphanum possible_brand  lev_distance  fuzzy_ratio
# 0                      False            NaN           NaN         51.0
# 1                       True            NaN           NaN         74.0
# 2                      False            NaN           NaN         62.0
# 3                       True            NaN           NaN         45.0
# 4                       True            NaN           NaN         51.0
# ...                      ...            ...           ...          ...
# 43996                   True            NaN           NaN         50.0
# 43997                   True            NaN           1.0         94.0
# 43998                   True            NaN           1.0         95.0
# 43999                   True            NaN           1.0         95.0
# 44000                   True            NaN           NaN         61.0
#
# [44001 rows x 8 columns]

# %%
final_res
# Out:
#                    product_name                   product_sku  \
# 0              Pupuk Urea N 46%                Urea Daun Buah
# 1       Pupuk Amonium Sulfat ZA              Ammonium Sulfate
# 2      Pupuk Super Fosfat SP-36   Triple Super Phospate (TSP)
# 3      Pupuk NPK Formula Khusus  Pak Tani Fertila  18-6-14+5S
# 4          Pupuk Organik Granul                   Urea Nitrea
# ...                         ...                           ...
# 43996        Maxxfosate Neo 1lt          Mahkota NP 16-20-12S
# 43997                    posgro                       Phosgro
# 43998                 ZA Pertro                      ZA Petro
# 43999                  nitralit                     Nitralite
# 44000       Urea Pril 50Kg PKT                     Urea Pusri
#
#                        clean_name                         clean_sku  \
# 0              pupuk urea n 46 %                    urea daun buah
# 1        pupuk amonium sulfat za                  ammonium sulfate
# 2       pupuk super fosfat sp -36      triple super phospate (tsp)
# 3       pupuk npk formula khusus    pak tani fertila 18x6x14 + 5 s
# 4           pupuk organik granul                       urea nitrea
# ...                           ...                               ...
# 43996        maxxfosate neo 1 lt             mahkota np 16x20x12 s
# 43997                     posgro                           phosgro
# 43998                  za pertro                          za petro
# 43999                   nitralit                         nitralite
# 44000        urea pril 50 kg pkt                        urea pusri
#
#        is_name_only_alphanum possible_brand  lev_distance  fuzzy_ratio
# 0                      False            NaN           NaN         51.0
# 1                       True            NaN           NaN         74.0
# 2                      False            NaN           NaN         62.0
# 3                       True            NaN           NaN         45.0
# 4                       True            NaN           NaN         51.0
# ...                      ...            ...           ...          ...
# 43996                   True            NaN           NaN         50.0
# 43997                   True            NaN           1.0         94.0
# 43998                   True            NaN           1.0         95.0
# 43999                   True            NaN           1.0         95.0
# 44000                   True            NaN           NaN         61.0
#
# [44001 rows x 8 columns]
