# %% [markdown]
# # Notebook for DSW Telkomsel 2023 - Party Parrot

# %%
import os
import re
import duckdb
import numpy as np
import pandas as pd

from fuzzywuzzy import fuzz
from tqdm import tqdm

# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# #  Exploration

# %%
df_name = pd.read_csv('datasets/processed/product_name.tsv', sep='\t')
catalog = pd.read_csv('datasets/processed/product_catalog.tsv', sep='\t')

# %%
name_counts = df_name.clean_name.value_counts()
name_counts.to_frame()
# Out:
#                                count
# clean_name
# sp - 26 @ 25 kg                    9
# phonska plus 15x15x15 @ 25 kg      9
# nitrea @ 50 kg                     8
# naga @ 1 liter                     7
# furadan @ 2 kg                     7
# ...                              ...
# simetal bisi321                    1
# urea curah                         1
# xycrot 400 ml                      1
# bhosep 250 ml                      1
# terong liberto hijau @ 5 gram      1
#
# [40680 rows x 1 columns]

# %%
joined = pd.merge(name_counts.to_frame().reset_index(), catalog[['sku_id', 'clean_sku']], how='cross')
joined
# Out:
#                             clean_name  count  sku_id       clean_sku
# 0                      sp - 26 @ 25 kg      9       0      urea petro
# 1                      sp - 26 @ 25 kg      9       1        urea pim
# 2                      sp - 26 @ 25 kg      9       2     urea nitrea
# 3                      sp - 26 @ 25 kg      9       3  urea daun buah
# 4                      sp - 26 @ 25 kg      9       4      urea pusri
# ...                                ...    ...     ...             ...
# 7607155  terong liberto hijau @ 5 gram      1     182        mestical
# 7607156  terong liberto hijau @ 5 gram      1     183     mesti - gas
# 7607157  terong liberto hijau @ 5 gram      1     184          mestac
# 7607158  terong liberto hijau @ 5 gram      1     185     mestikisrit
# 7607159  terong liberto hijau @ 5 gram      1     186  borate evermax
#
# [7607160 rows x 4 columns]

# %%
def is_name_token_present_in_sku(name, sku) -> bool:
    name_tokens = name.split()
    sku_tokens = sku.split()
    for token in name_tokens:
        if (len(token) <= 2 and token != 'za') or token in ['plus']:
            continue
        if token in sku_tokens:
            return True
    return False

duckdb.remove_function("is_name_token_present_in_sku")
duckdb.create_function("is_name_token_present_in_sku", is_name_token_present_in_sku)

# %%
hard_match = duckdb.query(
    """
    WITH cte AS (
        SELECT
            clean_name,
            clean_sku,
            sku_id,
            is_name_token_present_in_sku(clean_name, clean_sku) as is_token_in_name_in_sku
        FROM
            joined
    )

    SELECT
        *
    FROM
        cte
    WHERE is_token_in_name_in_sku
    """
).to_df()

# %%
np.random.seed(7)
hard_match.sample(20)
# Out:
#                                      clean_name  \
# 52665                          npk mutiara tani
# 2538                             urea non 50 kg
# 43997                 npk 16x16x16 mutiara 1 kg
# 23178                  npk 15x15x15 fus ns @ 50
# 37315                         sp 36 petro 50 kg
# 51639                         kangkung pak tani
# 27933      npk pak tani 16x16x16 kemasan 50 kg
# 23486  npk 13x6x27 + 4 mg + 0 , 65 b ns @ 50 kg
# 11876                 npk mutiara 16x16x16 @ 50
# 33768                         urea petronon sub
# 19507                          yaramila @ 50 kg
# 18996                       npk rajawali 500 ml
# 37377                         pupuk npk booster
# 57091              npk 16x16x16 @ 1 kg pak tani
# 11831                          kcl pak tani @ 5
# 12281  urea prill ns pt. pupuk kalimantan timur
# 46639                  npk nitrophoska 15x15x15
# 18799          npk pelangi jos 16x16x16 @ 50 kg
# 33375              yaramila 15920 kemasan 50 kg
# 55559                  npk dgw mutiara 16x16x16
#
#                                                clean_sku  sku_id  \
# 52665                            pak tani 16x16x16 merah      86
# 2538                                      urea daun buah       3
# 43997                              petro nitrat 16x16x16      37
# 23178                                npk pusri 15x15x15       33
# 37315                               rock phosphate petro      11
# 51639                  pak tani sawit 13x6x27 - 4x0x65 b      90
# 27933                                  cockhead 16x16x16     152
# 23486                            emcote 13x6x27 - 2 + te     169
# 11876                                   pelangi 16x16x16      31
# 33768                                        urea nitrea       2
# 19507                             yaramila faster 25x7x7     127
# 18996                         npk petro ningrat 12x11x20      41
# 37377                               npk kebomas 15x15x15      18
# 57091  npk kebomas 12x12x17 + 2 mgo + 0.1 zn + 0.2 b ...      16
# 11831                        pak tani sawit 12x12x17 - 2      89
# 12281                                         urea petro       0
# 46639                                  npk kujang 30x6x8      26
# 18799                              pelangi agro 20x10x10      29
# 33375                             yaramila unik 16x16x16     126
# 55559                  npk pusri 13x6x27 - 4 mg + 0.65 b      40
#
#        is_token_in_name_in_sku
# 52665                     True
# 2538                      True
# 43997                     True
# 23178                     True
# 37315                     True
# 51639                     True
# 27933                     True
# 23486                     True
# 11876                     True
# 33768                     True
# 19507                     True
# 18996                     True
# 37377                     True
# 57091                     True
# 11831                     True
# 12281                     True
# 46639                     True
# 18799                     True
# 33375                     True
# 55559                     True

# %%
df_name[~df_name.clean_name.isin(hard_match.clean_name.unique())]
# Out:
#        product_id                   product_name  is_name_only_alphanum  \
# 5               5           Pupuk Organik Granul                   True
# 6               6             Pupuk Organik Cair                   True
# 7               7                    Produk Lain                   True
# 8               8                         Rondap                   True
# 9               9                          Sekor                   True
# ...           ...                            ...                    ...
# 43996       43997      Extra one 680 EC @ 250 ml                  False
# 43997       43998      Extra One 680 SC @ 500 ml                  False
# 43998       43999      JARING ARWANA @ 100 METER                  False
# 43999       44000        Terong Puma F1 @ 5 gram                  False
# 44000       44001  Terong Liberto Hijau @ 5 gram                  False
#
#        is_name_only_alphabet                     clean_name  \
# 5                      False           pupuk organik granul
# 6                      False             pupuk organik cair
# 7                      False                    produk lain
# 8                       True                         rondap
# 9                       True                          sekor
# ...                      ...                            ...
# 43996                  False      extra one 680 ec @ 250 ml
# 43997                  False      extra one 680 sc @ 500 ml
# 43998                  False      jaring arwana @ 100 meter
# 43999                  False        terong puma f1 @ 5 gram
# 44000                  False  terong liberto hijau @ 5 gram
#
#        clean_name_non_formula clean_name_formula possible_brand
# 5        pupuk organik granul                NaN            NaN
# 6          pupuk organik cair                NaN            NaN
# 7                 produk lain                NaN            NaN
# 8                      rondap                NaN            NaN
# 9                       sekor                NaN            NaN
# ...                       ...                ...            ...
# 43996               extra one                NaN            NaN
# 43997               extra one                NaN            NaN
# 43998         jaring arwana @                NaN            NaN
# 43999           terong puma f                NaN            NaN
# 44000  terong liberto hijau @                NaN            NaN
#
# [36479 rows x 8 columns]

# %%
all_tokens = []
df_name.clean_name.apply(lambda x: all_tokens.extend(x.split(' ')))
all_tokens = [token for token in all_tokens if token.isalpha() and len(token) > 2]
all_tokens = pd.Series(all_tokens)
token_counts = all_tokens.value_counts()
token_counts.head(20)
# Out:
# npk        2048
# ltr        1060
# liter       923
# urea        704
# gram        703
# plus        543
# benih       539
# tani        386
# mutiara     384
# daun        367
# jagung      356
# pupuk       354
# merah       346
# kecil       339
# padi        327
# bibit       327
# petro       317
# kcl         300
# plastik     295
# pelangi     285
# Name: count, dtype: int64

# %%
name_counts[(name_counts <= 1) & (name_counts.index.str.len() <= 2)].sort_index()
# Out:
# clean_name
# 32    1
# 5     1
# 64    1
# 76    1
# 99    1
# a     1
# ap    1
# as    1
# b1    1
# bm    1
# es    1
# ff    1
# gl    1
# gp    1
# hk    1
# hp    1
# ki    1
# lp    1
# n5    1
# nk    1
# or    1
# rp    1
# sp    1
# ss    1
# ts    1
# ur    1
# w     1
# za    1
# zk    1
# Name: count, dtype: int64

# %% [markdown]
# # Post-analysis

# %%
final_res = pd.read_csv('datasets/processed/result_fuzzy.tsv', sep='\t')
print(set(range(44002)) - set(final_res.product_id.tolist()))
# final_res.to_csv('datasets/processed/final_result.tsv', sep='\t', index=False)
final_res
# Out:
# {5398}
#        product_id                   product_name               result_sku_lev  \
# 0               0               Pupuk Urea N 46%                  Urea Nitrea
# 1               1        Pupuk Amonium Sulfat ZA             Ammonium Sulfate
# 2               2       Pupuk Super Fosfat SP-36  Triple Super Phospate (TSP)
# 3               3              Pupuk NPK Phonska                    Fertiphos
# 4               4       Pupuk NPK Formula Khusus     Pak Tani Fertila 8-15-19
# ...           ...                            ...                          ...
# 43996       43997      Extra one 680 EC @ 250 ml          EMCOTE 13-6-27-2+TE
# 43997       43998      Extra One 680 SC @ 500 ml                    Petro-CAS
# 43998       43999      JARING ARWANA @ 100 METER             Mutiara 16-16-16
# 43999       44000        Terong Puma F1 @ 5 gram        MerokeCPN NK 15-15+TE
# 44000       44001  Terong Liberto Hijau @ 5 gram       PETROFERT  16-16-8+13S
#
#                   result_sku_fuzzy  result_sku_id_lev  result_sku_id_fuzzy  \
# 0                   Urea Daun Buah                  2                    3
# 1                   Nitroplus (ZA)                117                  131
# 2      Triple Super Phospate (TSP)                 64                   64
# 3       NPK Petro Ningrat 12-11-20                 78                   41
# 4             NPK Kebomas 15-15-15                101                   18
# ...                            ...                ...                  ...
# 43996       PETROFERT  16-16-8+13S                169                   19
# 43997       PETROFERT  16-16-8+13S                  9                   19
# 43998     Solution N 28-10-10 + TE                 52                   28
# 43999        MerokeCPN NK 15-15+TE                 55                   55
# 44000              Petro BioFertil                 19                   14
#
#       possible_brand  is_name_only_alphanum  is_name_only_alphabet  \
# 0                NaN                  False                  False
# 1                NaN                   True                  False
# 2                NaN                  False                  False
# 3               pihc                   True                  False
# 4                NaN                   True                  False
# ...              ...                    ...                    ...
# 43996            NaN                  False                  False
# 43997            NaN                  False                  False
# 43998            NaN                  False                  False
# 43999            NaN                  False                  False
# 44000            NaN                  False                  False
#
#          clean_name_non_formula  ...      result_clean_sku_fuzzy fuzzy_ratio  \
# 0                  pupuk urea n  ...              urea daun buah        44.0
# 1       pupuk amonium sulfat za  ...                nitroplus za        40.0
# 2       pupuk super fosfat sp -  ...   triple super phospate tsp        59.0
# 3             pupuk npk phonska  ...  npk petro ningrat 12x11x20        37.0
# 4      pupuk npk formula khusus  ...        npk kebomas 15x15x15        36.0
# ...                         ...  ...                         ...         ...
# 43996                 extra one  ...    petrofert 16x16x8 + 13 s        45.0
# 43997                 extra one  ...    petrofert 16x16x8 + 13 s        45.0
# 43998           jaring arwana @  ...    solution n 28x10x10 + te        45.0
# 43999             terong puma f  ...   merokecpn nk 15 - 15 + te        45.0
# 44000    terong liberto hijau @  ...             petro biofertil        41.0
#
#       lev_dist_lev lev_dist_fuzzy  lev_dist_lev_wo_form  \
# 0               12             13                   9.0
# 1               10             17                  10.0
# 2               15             15                  12.0
# 3               13             21                  13.0
# 4               17             19                  17.0
# ...            ...            ...                   ...
# 43996           18             19                  19.0
# 43997           19             19                   8.0
# 43998           19             20                  14.0
# 43999           16             16                  19.0
# 44000           21             22                  19.0
#
#        lev_dist_fuzzy_wo_form  is_name_token_present_in_sku_lev  \
# 0                        12.0                              True
# 1                        17.0                             False
# 2                        12.0                              True
# 3                        21.0                             False
# 4                        19.0                             False
# ...                       ...                               ...
# 43996                    21.0                             False
# 43997                    21.0                             False
# 43998                    20.0                             False
# 43999                    19.0                             False
# 44000                    15.0                             False
#
#        is_name_token_present_in_sku_fuzzy  cnt_common_tokens_lev  \
# 0                                    True                      1
# 1                                    True                      0
# 2                                    True                      1
# 3                                    True                      0
# 4                                    True                      0
# ...                                   ...                    ...
# 43996                               False                      0
# 43997                               False                      0
# 43998                               False                      0
# 43999                               False                      0
# 44000                               False                      0
#
#        cnt_common_tokens_fuzzy
# 0                            1
# 1                            1
# 2                            1
# 3                            1
# 4                            1
# ...                        ...
# 43996                        0
# 43997                        0
# 43998                        0
# 43999                        0
# 44000                        0
#
# [44001 rows x 23 columns]

# %%
final_res.loc[
    final_res['is_name_token_present_in_sku_fuzzy'] & (final_res['fuzzy_ratio'] >= 20),
    ['possible_brand', 'clean_name', 'result_clean_sku_lev', 'result_clean_sku_fuzzy', 'fuzzy_ratio', 'cnt_common_tokens_fuzzy']
]. \
    sort_values('fuzzy_ratio', ascending=True). \
    head(20)
# Out:
#       possible_brand                      clean_name  result_clean_sku_lev  \
# 1378             NaN                       boom padi                 borat
# 18952            NaN                         padi 05               phosgro
# 12047        mutiara                    hidro karate             nitralite
# 5944             NaN                        bom padi                 borat
# 23193            NaN                        padi all             fertikali
# 12380            NaN           phoenix perkutut gold            urea petro
# 40602            NaN  kno pn 2 kg merah / putih s .u  cpn pak tani 15x0x15
# 17384            NaN                 kcl jsb @ 50 kg            mesti - za
# 15657            NaN                  kcl 88 1 liter             nitralite
# 32420           yara                       yaravita               yaravera
# 13451            NaN                  herbisida padi             fertikali
# 43180            NaN                       jos bubub               rp peru
# 43181            NaN                      jos bubuk                rp peru
# 26702            NaN                  kcl + + 500 ml             dgw kno 3
# 39848            NaN                       jos bubuk               rp peru
# 37281            NaN                     baligro npk             phosgreen
# 8313             NaN                    padi kencana           za pak tani
# 43122            NaN                        cuka jos                  hxas
# 18505            NaN                   touchdown neo               brucite
# 34926            NaN                    padi kunoing             dgw kno 3
#
#                                   result_clean_sku_fuzzy  fuzzy_ratio  \
# 1378            pak tani padi 21x14x7 + 2 mgo + 2 s + te         20.0
# 18952           pak tani padi 21x14x7 + 2 mgo + 2 s + te         21.0
# 12047       karate plus boroni 15.5x0x0 + 0.3 s + 26 cao         21.0
# 5944            pak tani padi 21x14x7 + 2 mgo + 2 s + te         21.0
# 23193           pak tani padi 21x14x7 + 2 mgo + 2 s + te         21.0
# 12380                                  gold dgw 16x10x18         21.0
# 40602                                          dgw kno 3         21.0
# 17384                             mahkota mop kcl canada         22.0
# 15657                             mahkota mop kcl canada         22.0
# 32420  yaravita tri - pholate 0x0x0 - 70 mn + 50 zn +...         22.0
# 13451           pak tani padi 21x14x7 + 2 mgo + 2 s + te         22.0
# 43180               pelangi jos 16x16x16 coating mikroba         22.0
# 43181               pelangi jos 16x16x16 coating mikroba         22.0
# 26702                             mahkota mop kcl canada         22.0
# 39848               pelangi jos 16x16x16 coating mikroba         22.0
# 37281                                   npk pim 15x15x15         22.0
# 8313            pak tani padi 21x14x7 + 2 mgo + 2 s + te         23.0
# 43122               pelangi jos 16x16x16 coating mikroba         23.0
# 18505                             neo kristalon 12x12x36         23.0
# 34926           pak tani padi 21x14x7 + 2 mgo + 2 s + te         23.0
#
#        cnt_common_tokens_fuzzy
# 1378                         1
# 18952                        1
# 12047                        1
# 5944                         1
# 23193                        1
# 12380                        1
# 40602                        1
# 17384                        1
# 15657                        1
# 32420                        1
# 13451                        1
# 43180                        1
# 43181                        1
# 26702                        1
# 39848                        1
# 37281                        1
# 8313                         1
# 43122                        1
# 18505                        1
# 34926                        1

# %%
cond1 = (
    False
    | (final_res.is_name_token_present_in_sku_fuzzy & (final_res.fuzzy_ratio >= 28))
    | ((final_res.cnt_common_tokens_fuzzy >= 2) & (final_res.fuzzy_ratio >= 28))
    | (final_res.possible_brand.notnull() & (final_res.fuzzy_ratio >= 55))
    | (final_res.possible_brand.isnull()  & (final_res.fuzzy_ratio >= 61))
    | (final_res['lev_dist_fuzzy_wo_form'] <= 1)
    | (final_res['lev_dist_fuzzy'] <= 1)
    | (final_res['lev_dist_lev'] <= 1)
    | (final_res['lev_dist_lev_wo_form'] <= 1)
)
print(final_res[cond1].shape)

final_res.loc[
    cond1,
    ['clean_name', 'result_clean_sku_fuzzy', 'fuzzy_ratio', 'cnt_common_tokens_fuzzy']
] \
  .sort_values('fuzzy_ratio') \
  .head(20)
# Out:
# (8118, 23)
#                         clean_name                    result_clean_sku_fuzzy  \
# 40504  kno 3 putih kanitrat @ 1 kg                                 dgw kno 3
# 3003                       kcl mkt                    mahkota mop kcl canada
# 15312                 barrier gold                         gold dgw 16x10x18
# 41938                do tsp meroke            meroke flex - g 8x9x39 + 3 mgo
# 41937                do kcl meroke            meroke flex - g 8x9x39 + 3 mgo
# 18137                 santi - gold                         gold dgw 16x10x18
# 6640                kcl flake 5 kg                    mahkota mop kcl canada
# 17946         crumble merah burung                   pak tani 16x16x16 merah
# 13277     bibit padi ir nutri zinc  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 13273    bibit padi ir cakrabuana   pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 6092                unik npk 50 kg                    yaramila unik 16x16x16
# 8784                    multi padi  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 33617            benih padi kukuku  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 8969            bibit padi drupadi  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 40390                      kcl opp                    mahkota mop kcl canada
# 21718            benih padi inpari  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 40121           padi ciherang 5 kg  pak tani padi 21x14x7 + 2 mgo + 2 s + te
# 9295                ember biru bsr                    pak tani 16x16x16 biru
# 6318           pupuk aceh cap kopi                         cap tawon 18x12x6
# 37375          timun lumintu gold                          gold dgw 16x10x18
#
#        fuzzy_ratio  cnt_common_tokens_fuzzy
# 40504         28.0                        2
# 3003          28.0                        1
# 15312         28.0                        1
# 41938         28.0                        1
# 41937         28.0                        1
# 18137         28.0                        1
# 6640          28.0                        1
# 17946         28.0                        1
# 13277         28.0                        1
# 13273         28.0                        1
# 6092          28.0                        1
# 8784          28.0                        1
# 33617         28.0                        1
# 8969          28.0                        1
# 40390         28.0                        1
# 21718         28.0                        1
# 40121         28.0                        1
# 9295          28.0                        1
# 6318          28.0                        1
# 37375         28.0                        1

# %%
low_fuzzy = final_res[final_res.fuzzy_ratio.between(0, 40)]
low_fuzzy.sort_values(['fuzzy_ratio', 'cnt_common_tokens_fuzzy', 'lev_dist_fuzzy'])
# Out:
#        product_id                            product_name  \
# 37233       37234                                       5
# 3552         3552                                  zzzzzz
# 25048       25049                                 ??????
# 15398       15399                                      Ff
# 15763       15764                                 dhddbbf
# ...           ...                                     ...
# 26277       26278                    ABACEL 18EC (1LITER)
# 38329       38330             demolis. 100ml. (abamectin)
# 8808         8809            Bentan -45WP (100x100 gram)
# 8169         8170   Filia 50mL (trisiklazol,propikonazol)
# 16766       16767  Starban 100mL(klorpirifos,sipermetrin)
#
#                     result_sku_lev             result_sku_fuzzy  \
# 37233                          KSP               MK FOS 0-52-34
# 3552                         Borat                     MerokeZA
# 25048                        Borat                      DGW TSP
# 15398                          KSP                    Fertikali
# 15763                      DGW TSP               Urea Daun Buah
# ...                            ...                          ...
# 26277               Nitroplus (ZA)  Triple Super Phospate (TSP)
# 38329               Nitroplus (ZA)               Nitroplus (ZA)
# 8808      Mahkota MOP (KCL Canada)               Nitroplus (ZA)
# 8169      Mahkota MOP (KCL Canada)     Mahkota MOP (KCL Canada)
# 16766  Triple Super Phospate (TSP)  Triple Super Phospate (TSP)
#
#        result_sku_id_lev  result_sku_id_fuzzy possible_brand  \
# 37233                134                  132            NaN
# 3552                  66                   43            NaN
# 25048                 66                  145            NaN
# 15398                134                   82            NaN
# 15763                145                    3            NaN
# ...                  ...                  ...            ...
# 26277                131                   64            NaN
# 38329                131                  131            NaN
# 8808                  67                  131            NaN
# 8169                  67                   67            NaN
# 16766                 64                   64            NaN
#
#        is_name_only_alphanum  is_name_only_alphabet clean_name_non_formula  \
# 37233                   True                  False                    NaN
# 3552                    True                   True                 zzzzzz
# 25048                  False                  False                 ??????
# 15398                   True                   True                     ff
# 15763                   True                   True                dhddbbf
# ...                      ...                    ...                    ...
# 26277                  False                  False                 abacel
# 38329                  False                  False              demolis .
# 8808                   False                  False               bentan -
# 8169                   False                  False                  filia
# 16766                  False                  False                starban
#
#        ...                                     clean_name  \
# 37233  ...                                              5
# 3552   ...                                         zzzzzz
# 25048  ...                                        ??????
# 15398  ...                                             ff
# 15763  ...                                        dhddbbf
# ...    ...                                            ...
# 26277  ...                      abacel 18 ec ( 1 liter )
# 38329  ...              demolis . 100 ml . ( abamectin )
# 8808   ...              bentan - 45 wp ( 100 x100 gram )
# 8169   ...    filia 50 ml ( trisiklazol , propikonazol )
# 16766  ...  starban 100 ml ( klorpirifos , sipermetrin )
#
#                  result_clean_sku_lev          result_clean_sku_fuzzy  \
# 37233                             ksp                  mk fos 0x52x34
# 3552                            borat                        merokeza
# 25048                           borat                         dgw tsp
# 15398                             ksp                       fertikali
# 15763                         dgw tsp                  urea daun buah
# ...                               ...                             ...
# 26277               nitroplus ( za )   triple super phospate ( tsp )
# 38329               nitroplus ( za )                nitroplus ( za )
# 8808      mahkota mop ( kcl canada )                nitroplus ( za )
# 8169      mahkota mop ( kcl canada )      mahkota mop ( kcl canada )
# 16766  triple super phospate ( tsp )   triple super phospate ( tsp )
#
#       fuzzy_ratio  lev_dist_lev  lev_dist_fuzzy  lev_dist_lev_wo_form  \
# 37233        13.0             3              13                   NaN
# 3552         14.0             6               7                   6.0
# 25048        14.0             7               7                   6.0
# 15398        18.0             3               8                   3.0
# 15763        19.0             6              12                   6.0
# ...           ...           ...             ...                   ...
# 26277        40.0            19              22                  16.0
# 38329        40.0            24              24                  13.0
# 8808         40.0            23              25                  23.0
# 8169         40.0            31              31                  25.0
# 16766        40.0            33              33                  27.0
#
#        lev_dist_fuzzy_wo_form  cnt_common_tokens_lev  cnt_common_tokens_fuzzy
# 37233                     NaN                      0                        0
# 3552                      7.0                      0                        0
# 25048                     7.0                      0                        0
# 15398                     8.0                      0                        0
# 15763                    12.0                      0                        0
# ...                       ...                    ...                      ...
# 26277                    28.0                      3                        3
# 38329                    13.0                      3                        3
# 8808                     16.0                      3                        3
# 8169                     25.0                      3                        3
# 16766                    27.0                      3                        3
#
# [7645 rows x 21 columns]

# %%
final_res.loc[
    final_res.fuzzy_ratio.between(70, 80),
    ['product_id', 'clean_name', 'result_clean_sku_lev', 'result_clean_sku_fuzzy', 'fuzzy_ratio']
] \
    .sort_values('fuzzy_ratio') \
    .iloc[list(range(10)) + list(range(-10, 0))]
# Out:
#        product_id                  clean_name     result_clean_sku_lev  \
# 41629       41630  urea prl daun buah @ 50 kg           urea daun buah
# 22233       22234             za petro 50 kg                  za petro
# 27425       27426                 npk nitrate                nitralite
# 19351       19352  npk pelangi 12.12x17x2 bld  npk pelangi 13x6x27 - 4
# 41009       41010        pupuk kaptan kebomas  kapur pertanian kebomas
# 21036       21037           npk kujang 25 kg         npk kujang 30x6x8
# 27419       27420       lao ying 16x16x16 @ 1   pak tani 16x16x16 biru
# 40920       40921                meroke saset                meroketsp
# 35209       35210               urea pet 5 kg               urea petro
# 35415       35416  urea prl @ 50 kg daun buah           urea daun buah
# 6160         6161                npk 16x16x16         nitroku 16x16x16
# 13293       13294             urea pusri 5 kg               urea pusri
# 13198       13199    npk dgw mutiara 16x16x16         mutiara 16x16x16
# 34308       34309             kebomas 15x15x6     npk kebomas 15x15x15
# 12293       12294          npk kujang 24x6x15        npk kujang 30x6x8
# 6256         6257                  urea prill                 urea pim
# 41006       41007       urea daun buah laltim           urea daun buah
# 32734       32735                zk petro @ 1                 zk petro
# 13526       13527         npk mutiara 16 1616         mutiara 16x16x16
# 36814       36815    mutiara 16x16x16 @ 50 kg         mutiara 16x16x16
#
#         result_clean_sku_fuzzy  fuzzy_ratio
# 41629           urea daun buah         70.0
# 22233                 za petro         70.0
# 27425                nitralite         70.0
# 19351     pelangi 12x12x17 - 2         70.0
# 41009  kapur pertanian kebomas         70.0
# 21036     npk kujang 15x15x15          70.0
# 27419         pelangi 16x16x16         70.0
# 40920                 merokeza         70.0
# 35209               urea petro         70.0
# 35415           urea daun buah         70.0
# 6160        npk pusri 16x16x16         80.0
# 13293               urea pusri         80.0
# 13198         mutiara 16x16x16         80.0
# 34308     npk kebomas 15x15x15         80.0
# 12293        npk kujang 30x6x8         80.0
# 6256                urea pusri         80.0
# 41006           urea daun buah         80.0
# 32734                 zk petro         80.0
# 13526         mutiara 16x16x16         80.0
# 36814         mutiara 16x16x16         80.0

# %%
final_res.loc[
    ~cond1 & (final_res.fuzzy_ratio.between(61, 62)),
    ['product_id', 'clean_name', 'result_clean_sku_lev', 'result_clean_sku_fuzzy', 'fuzzy_ratio']
] \
    .sort_values('fuzzy_ratio') \
    .iloc[list(range(10)) + list(range(-10, 0))]
# Out:
#        product_id                        clean_name  \
# 2               2        pupuk super fosfat sp - 36
# 33324       33325  urea granul daun buah @50 kg ns
# 18378       18379           kasur panjang + kelambu
# 33332       33333                     urea ganul ns
# 18005       18006              polibag 7 , 5/15 x15
# 33381       33382  urea granul daun buah @50 kg ns
# 16827       16828                      methox 42 sp
# 34360       34361                     envirophos 36
# 15428       15429                    ponska grentop
# 34787       34788                  calsium multimex
# 19923       19924                             metro
# 19628       19629                           green11
# 19627       19628                           green22
# 19456       19457             npk 16x16x16 su 50 kg
# 19098       19099                             menir
# 18797       18798                          cpn kno3
# 18742       18743                            romero
# 18684       18685                    16x16x16 elang
# 19688       19689                           segreng
# 43855       43856                            mota 2
#
#                  result_clean_sku_lev          result_clean_sku_fuzzy  \
# 2      triple super phospate ( tsp )   triple super phospate ( tsp )
# 33324                  urea daun buah                  urea daun buah
# 18378         kapur pertanian kebomas         kapur pertanian kebomas
# 33332                  urea daun buah                      urea pusri
# 18005                pelangi 15x15x15                pelangi 15x15x15
# 33381                  urea daun buah                  urea daun buah
# 16827                       meroketsp                     mesti - tsp
# 34360                       fertiphos            nitrophoska 13x10x20
# 15428                       phosgreen                       phosgreen
# 34787               magnesium sulfate               magnesium sulfate
# 19923                          mestac                        za petro
# 19628                            vrea                       phosgreen
# 19627                            vrea                       phosgreen
# 19456                 dgw 16x16x16+te              npk pusri 16x16x16
# 19098                          mestac                        rp mesir
# 18797                        dgw kno3                        dgw kno3
# 18742                         phosgro                      merokerock
# 18684                 dgw 16x16x16+te                 dgw 16x16x16+te
# 19688                            vrea                       phosgreen
# 43855                           borat                      mahkota za
#
#        fuzzy_ratio
# 2             61.0
# 33324         61.0
# 18378         61.0
# 33332         61.0
# 18005         61.0
# 33381         61.0
# 16827         61.0
# 34360         61.0
# 15428         61.0
# 34787         61.0
# 19923         62.0
# 19628         62.0
# 19627         62.0
# 19456         62.0
# 19098         62.0
# 18797         62.0
# 18742         62.0
# 18684         62.0
# 19688         62.0
# 43855         62.0
